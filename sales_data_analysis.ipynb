# %%
columns = []
data = [[],[],[],[],[]]

# %%
def insert_row(data,l):
    for i in range(len(l)):
        data[i].append(l[i])
    return data

# %%
with open('sales-data.txt','r') as f:
    columns = f.readline().strip('\n').split(',')
    for row in f.readlines():
        data_row = (row.strip('\n').split(','))
        data = insert_row(data, data_row)

# %%
columns
# Out:
# ['Date', 'SKU', 'Unit Price', 'Quantity', 'Total Price']

# %%
[len(x) for x in data]
# Out:
# [13939, 13939, 13939, 13939, 13939]

# %%
dataset = dict(zip(columns,data))

# %%
dataset
# Out:
# {'Date': ['2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-01',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-02',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-03',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-04',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-05',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-06',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   '2019-01-07',
#   ...],
#  'SKU': ['Death by Chocolate',
#   'Cake Fudge',
#   'Cake Fudge',
#   'Cake Fudge',
#   'Death by Chocolate',
#   'Vanilla Double Scoop',
#   'Butterscotch Single Scoop',
#   'Vanilla Single Scoop',
#   'Cake Fudge',
#   'Hot Chocolate Fudge',
#   'Butterscotch Single Scoop',
#   'Chocolate Europa Double Scoop',
#   'Hot Chocolate Fudge',
#   'Caramel Crunch Single Scoop',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Cafe Caramel',
#   'Vanilla Double Scoop',
#   'Butterscotch Single Scoop',
#   'Butterscotch Single Scoop',
#   'Vanilla Single Scoop',
#   'Butterscotch Single Scoop',
#   'Vanilla Double Scoop',
#   'Death by Chocolate',
#   'Cafe Caramel',
#   'Pista Single Scoop',
#   'Hot Chocolate Fudge',
#   'Vanilla Single Scoop',
#   'Vanilla Single Scoop',
#   'Cake Fudge',
#   'Vanilla Single Scoop',
#   'Vanilla Double Scoop',
#   'Cake Fudge',
#   'Vanilla Double Scoop',
#   'Hot Chocolate Fudge',
#   'Vanilla Double Scoop',
#   'Vanilla Double Scoop',
#   'Hot Chocolate Fudge',
#   'Cake Fudge',
#   'Vanilla Single Scoop',
#   'Cake Fudge',
#   'Pista Single Scoop',
#   'Butterscotch Single Scoop',
#   'Vanilla Double Scoop',
#   'Cafe Caramel',
#   'Cake Fudge',
#   'Trilogy',
#   'Butterscotch Single Scoop',
#   'Death by Chocolate',
#   'Butterscotch Single Scoop',
#   'Hot Chocolate Fudge',
#   'Cake Fudge',
#   'Cake Fudge',
#   'Vanilla Single Scoop',
#   'Cafe Caramel',
#   'Cake Fudge',
#   'Cafe Caramel',
#   'Almond Fudge',
#   'Cake Fudge',
#   'Death by Chocolate',
#   'Death by Chocolate',
#   'Hot Chocolate Fudge',
#   'Cake Fudge',
#   'Cake Fudge',
#   'Butterscotch Single Scoop',
#   'Vanilla Double Scoop',
#   'Death by Chocolate',
#   'Caramel Crunch Double Scoop',
#   'Vanilla Single Scoop',
#   'Hot Chocolate Fudge',
#   'Vanilla Double Scoop',
#   'Cafe Caramel',
#   'Vanilla Double Scoop',
#   'Death by Chocolate',
#   'Vanilla Double Scoop',
#   'Vanilla Single Scoop',
#   'Cafe Caramel',
#   'Vanilla Double Scoop',
#   'Death by Chocolate',
#   'Hot Chocolate Fudge',
#   'Pista Single Scoop',
#   'Cake Fudge',
#   'Hot Chocolate Fudge',
#   'Vanilla Single Scoop',
#   'Dry Fruit Double Scoop',
#   'Butterscotch Single Scoop',
#   'Cake Fudge',
#   'Vanilla Double Scoop',
#   'Dry Fruit Single Scoop',
#   'Cafe Caramel',
#   'Hot Chocolate Fudge',
#   'Chocolate Europa Double Scoop',
#   'Rocky Road Single Scoop',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Vanilla Double Scoop',
#   'Cafe Caramel',
#   'Vanilla Double Scoop',
#   'Vanilla Double Scoop',
#   'Cake Fudge',
#   'Vanilla Single Scoop',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Vanilla Double Scoop',
#   'Vanilla Single Scoop',
#   'Vanilla Double Scoop',
#   'Vanilla Single Scoop',
#   'Vanilla Single Scoop',
#   'Mint Fudge',
#   'Butterscotch Single Scoop',
#   'Vanilla Single Scoop',
#   'Hot Chocolate Fudge',
#   'Vanilla Single Scoop',
#   'Death by Chocolate',
#   'Dry Fruit Double Scoop',
#   'Vanilla Single Scoop',
#   'Butterscotch Single Scoop',
#   'Vanilla Single Scoop',
#   'Cake Fudge',
#   'Vanilla Double Scoop',
#   'Vanilla Double Scoop',
#   'Chocolate Europa Double Scoop',
#   'Death by Chocolate',
#   'Hot Chocolate Fudge',
#   'Death by Chocolate',
#   'Cake Fudge',
#   'Cafe Caramel',
#   'Fig and Honey Double Scoop',
#   'Cake Fudge',
#   'Vanilla Single Scoop',
#   'Death by Chocolate',
#   'Cake Fudge',
#   'Hot Chocolate Fudge',
#   'Chocolate Europa Single Scoop',
#   'Butterscotch Single Scoop',
#   'Butterscotch Double Scoop',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Fig and Honey Single Scoop',
#   'Butterscotch Single Scoop',
#   'Cake Fudge',
#   'Vanilla Single Scoop',
#   'Pista Double Scoop',
#   'Caramel Crunch Double Scoop',
#   'Vanilla Double Scoop',
#   'Death by Chocolate',
#   'Butterscotch Double Scoop',
#   'Vanilla Double Scoop',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Cake Fudge',
#   'Cafe Caramel',
#   'Cafe Caramel',
#   'Vanilla Double Scoop',
#   'Butterscotch Single Scoop',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Butterscotch Single Scoop',
#   'Pista Single Scoop',
#   'Death by Chocolate',
#   'Hot Chocolate Fudge',
#   'Death by Chocolate',
#   'Banana Split',
#   'Hot Chocolate Fudge',
#   'Almond Fudge',
#   'Pista Single Scoop',
#   'Caramel Crunch Double Scoop',
#   'Banana Split',
#   'Death by Chocolate',
#   'Cake Fudge',
#   'Hot Chocolate Fudge',
#   'Vanilla Double Scoop',
#   'Cake Fudge',
#   'Vanilla Double Scoop',
#   'Hot Chocolate Fudge',
#   'Vanilla Double Scoop',
#   'Death by Chocolate',
#   'Vanilla Double Scoop',
#   'Hot Chocolate Fudge',
#   'Death by Chocolate',
#   'Banana Split',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Butterscotch Single Scoop',
#   'Death by Chocolate',
#   'Butterscotch Single Scoop',
#   'Butterscotch Single Scoop',
#   'Death by Chocolate',
#   'Death by Chocolate',
#   'Death by Chocolate',
#   'Death by Chocolate',
#   'Hot Chocolate Fudge',
#   'Vanilla Double Scoop',
#   'Cafe Caramel',
#   'Cake Fudge',
#   'Vanilla Double Scoop',
#   'Death by Chocolate',
#   'Vanilla Single Scoop',
#   'Death by Chocolate',
#   'Cafe Caramel',
#   'Butterscotch Single Scoop',
#   'Butterscotch Single Scoop',
#   'Vanilla Double Scoop',
#   'Cake Fudge',
#   'Vanilla Double Scoop',
#   'Cafe Caramel',
#   'Fig and Honey Double Scoop',
#   'Hot Chocolate Fudge',
#   'Vanilla Single Scoop',
#   'Hot Chocolate Fudge',
#   'Death by Chocolate',
#   'Vanilla Single Scoop',
#   'Vanilla Double Scoop',
#   'Death by Chocolate',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Cake Fudge',
#   'Vanilla Single Scoop',
#   'Butterscotch Single Scoop',
#   'Hot Chocolate Fudge',
#   'Fig and Honey Single Scoop',
#   'Vanilla Single Scoop',
#   'Death by Chocolate',
#   'Butterscotch Single Scoop',
#   'Hot Chocolate Fudge',
#   'Vanilla Single Scoop',
#   'Hot Chocolate Fudge',
#   'Butterscotch Single Scoop',
#   'Cake Fudge',
#   'Vanilla Single Scoop',
#   'Vanilla Double Scoop',
#   'Vanilla Double Scoop',
#   'Dry Fruit Double Scoop',
#   'Death by Chocolate',
#   'Death by Chocolate',
#   'Hot Chocolate Fudge',
#   'Cake Fudge',
#   'Vanilla Double Scoop',
#   'Cake Fudge',
#   'Cake Fudge',
#   'Vanilla Double Scoop',
#   'Banana Split',
#   'Caramel Crunch Single Scoop',
#   'Cafe Caramel',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Death by Chocolate',
#   'Vanilla Double Scoop',
#   'Cafe Caramel',
#   'Cafe Caramel',
#   'Butterscotch Single Scoop',
#   'Vanilla Double Scoop',
#   'Hot Chocolate Fudge',
#   'Banana Split',
#   'Fig and Honey Single Scoop',
#   'Hot Chocolate Fudge',
#   'Pista Single Scoop',
#   'Vanilla Double Scoop',
#   'Vanilla Double Scoop',
#   'Cake Fudge',
#   'Hot Chocolate Fudge',
#   'Vanilla Double Scoop',
#   'Cake Fudge',
#   'Dry Fruit Double Scoop',
#   'Hot Chocolate Fudge',
#   'Death by Chocolate',
#   'Hot Chocolate Fudge',
#   'Vanilla Single Scoop',
#   'Death by Chocolate',
#   'Rocky Road Single Scoop',
#   'Dry Fruit Double Scoop',
#   'Hot Chocolate Fudge',
#   'Vanilla Double Scoop',
#   'Cafe Caramel',
#   'Vanilla Double Scoop',
#   'Butterscotch Single Scoop',
#   'Rocky Road Double Scoop',
#   'Cake Fudge',
#   'Vanilla Double Scoop',
#   'Death by Chocolate',
#   'Cake Fudge',
#   'Hot Chocolate Fudge',
#   'Vanilla Double Scoop',
#   'Hot Chocolate Fudge',
#   'Vanilla Double Scoop',
#   'Cafe Caramel',
#   'Hot Chocolate Fudge',
#   'Cafe Caramel',
#   'Vanilla Double Scoop',
#   'Vanilla Double Scoop',
#   'Butterscotch Single Scoop',
#   'Vanilla Single Scoop',
#   'Rocky Road Double Scoop',
#   'Cafe Caramel',
#   'Cake Fudge',
#   'Vanilla Double Scoop',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Vanilla Single Scoop',
#   'Death by Chocolate',
#   'Caramel Crunch Double Scoop',
#   'Butterscotch Single Scoop',
#   'Cafe Caramel',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Cake Fudge',
#   'Butterscotch Single Scoop',
#   'Vanilla Double Scoop',
#   'Hot Chocolate Fudge',
#   'Vanilla Single Scoop',
#   'Hot Chocolate Fudge',
#   'Butterscotch Single Scoop',
#   'Death by Chocolate',
#   'Vanilla Single Scoop',
#   'Cake Fudge',
#   'Cake Fudge',
#   'Hot Chocolate Fudge',
#   'Death by Chocolate',
#   'Vanilla Double Scoop',
#   'Vanilla Single Scoop',
#   'Vanilla Double Scoop',
#   'Death by Chocolate',
#   'Hot Chocolate Fudge',
#   'Butterscotch Single Scoop',
#   'Vanilla Double Scoop',
#   'Butterscotch Single Scoop',
#   'Vanilla Double Scoop',
#   'Pista Single Scoop',
#   'Rocky Road Double Scoop',
#   'Hot Chocolate Fudge',
#   'Fig and Honey Double Scoop',
#   'Hot Chocolate Fudge',
#   'Vanilla Double Scoop',
#   'Cafe Caramel',
#   'Dry Fruit Single Scoop',
#   'Vanilla Single Scoop',
#   'Death by Chocolate',
#   'Vanilla Double Scoop',
#   'Vanilla Single Scoop',
#   'Vanilla Single Scoop',
#   'Butterscotch Single Scoop',
#   'Hot Chocolate Fudge',
#   'Vanilla Double Scoop',
#   'Hot Chocolate Fudge',
#   'Vanilla Single Scoop',
#   'Cake Fudge',
#   'Hot Chocolate Fudge',
#   'Dew Drop Sundae',
#   'Hot Chocolate Fudge',
#   'Vanilla Single Scoop',
#   'Chocolate Europa Double Scoop',
#   'Butterscotch Single Scoop',
#   'Butterscotch Single Scoop',
#   'Hot Chocolate Fudge',
#   'Pista Double Scoop',
#   'Vanilla Double Scoop',
#   'Vanilla Double Scoop',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Butterscotch Single Scoop',
#   'Vanilla Double Scoop',
#   'Pista Double Scoop',
#   'Vanilla Double Scoop',
#   'Cake Fudge',
#   'Cake Fudge',
#   'Hot Chocolate Fudge',
#   'Butterscotch Single Scoop',
#   'Death by Chocolate',
#   'Butterscotch Single Scoop',
#   'Rocky Road Single Scoop',
#   'Vanilla Double Scoop',
#   'Cake Fudge',
#   'Vanilla Double Scoop',
#   'Cake Fudge',
#   'Hot Chocolate Fudge',
#   'Rocky Road Double Scoop',
#   'Death by Chocolate',
#   'Vanilla Double Scoop',
#   'Vanilla Single Scoop',
#   'Cake Fudge',
#   'Caramel Crunch Single Scoop',
#   'Death by Chocolate',
#   'Hot Chocolate Fudge',
#   'Cake Fudge',
#   'Butterscotch Single Scoop',
#   'Vanilla Double Scoop',
#   'Pista Double Scoop',
#   'Vanilla Double Scoop',
#   'Dry Fruit Double Scoop',
#   'Almond Fudge',
#   'Butterscotch Single Scoop',
#   'Vanilla Double Scoop',
#   'Dry Fruit Double Scoop',
#   'Vanilla Double Scoop',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Vanilla Single Scoop',
#   'Vanilla Double Scoop',
#   'Death by Chocolate',
#   'Cake Fudge',
#   'Vanilla Double Scoop',
#   'Vanilla Single Scoop',
#   'Hot Chocolate Fudge',
#   'Vanilla Double Scoop',
#   'Hot Chocolate Fudge',
#   'Vanilla Double Scoop',
#   'Cake Fudge',
#   'Pista Single Scoop',
#   'Cake Fudge',
#   'Vanilla Single Scoop',
#   'Trilogy',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Vanilla Double Scoop',
#   'Hot Chocolate Fudge',
#   'Dry Fruit Single Scoop',
#   'Fig and Honey Double Scoop',
#   'Dew Drop Sundae',
#   'Hot Chocolate Fudge',
#   'Vanilla Single Scoop',
#   'Vanilla Double Scoop',
#   'Cafe Caramel',
#   'Hot Chocolate Fudge',
#   'Butterscotch Single Scoop',
#   'Hot Chocolate Fudge',
#   'Butterscotch Single Scoop',
#   'Cafe Caramel',
#   'Hot Chocolate Fudge',
#   'Vanilla Double Scoop',
#   'Hot Chocolate Fudge',
#   'Butterscotch Single Scoop',
#   'Vanilla Double Scoop',
#   'Chocolate Europa Single Scoop',
#   'Vanilla Double Scoop',
#   'Mint Fudge',
#   'Death by Chocolate',
#   'Hot Chocolate Fudge',
#   'Chocolate Europa Single Scoop',
#   'Hot Chocolate Fudge',
#   'Death by Chocolate',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Vanilla Single Scoop',
#   'Hot Chocolate Fudge',
#   'Butterscotch Single Scoop',
#   'Vanilla Single Scoop',
#   'Vanilla Double Scoop',
#   'Vanilla Double Scoop',
#   'Pista Double Scoop',
#   'Death by Chocolate',
#   'Vanilla Single Scoop',
#   'Cafe Caramel',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Cake Fudge',
#   'Vanilla Single Scoop',
#   'Butterscotch Single Scoop',
#   'Vanilla Double Scoop',
#   'Cake Fudge',
#   'Hot Chocolate Fudge',
#   'Vanilla Single Scoop',
#   'Vanilla Single Scoop',
#   'Cake Fudge',
#   'Cake Fudge',
#   'Vanilla Double Scoop',
#   'Cake Fudge',
#   'Cafe Caramel',
#   'Death by Chocolate',
#   'Fig and Honey Double Scoop',
#   'Death by Chocolate',
#   'Hot Chocolate Fudge',
#   'Vanilla Double Scoop',
#   'Hot Chocolate Fudge',
#   'Cake Fudge',
#   'Butterscotch Single Scoop',
#   'Cake Fudge',
#   'Mint Fudge',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Vanilla Double Scoop',
#   'Cafe Caramel',
#   'Dew Drop Sundae',
#   'Vanilla Double Scoop',
#   'Caramel Crunch Double Scoop',
#   'Butterscotch Single Scoop',
#   'Vanilla Double Scoop',
#   'Cake Fudge',
#   'Vanilla Single Scoop',
#   'Vanilla Double Scoop',
#   'Hot Chocolate Fudge',
#   'Death by Chocolate',
#   'Butterscotch Single Scoop',
#   'Cake Fudge',
#   'Cake Fudge',
#   'Hot Chocolate Fudge',
#   'Cake Fudge',
#   'Cake Fudge',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Dry Fruit Single Scoop',
#   'Fig and Honey Single Scoop',
#   'Vanilla Double Scoop',
#   'Vanilla Double Scoop',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Vanilla Single Scoop',
#   'Pista Double Scoop',
#   'Hot Chocolate Fudge',
#   'Butterscotch Single Scoop',
#   'Hot Chocolate Fudge',
#   'Chocolate Europa Double Scoop',
#   'Hot Chocolate Fudge',
#   'Death by Chocolate',
#   'Hot Chocolate Fudge',
#   'Caramel Crunch Double Scoop',
#   'Hot Chocolate Fudge',
#   'Butterscotch Single Scoop',
#   'Cake Fudge',
#   'Hot Chocolate Fudge',
#   'Butterscotch Single Scoop',
#   'Death by Chocolate',
#   'Hot Chocolate Fudge',
#   'Butterscotch Double Scoop',
#   'Cafe Caramel',
#   'Hot Chocolate Fudge',
#   'Butterscotch Single Scoop',
#   'Cake Fudge',
#   'Butterscotch Single Scoop',
#   'Death by Chocolate',
#   'Dry Fruit Double Scoop',
#   'Hot Chocolate Fudge',
#   'Vanilla Single Scoop',
#   'Vanilla Double Scoop',
#   'Cake Fudge',
#   'Vanilla Double Scoop',
#   'Cafe Caramel',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Cake Fudge',
#   'Hot Chocolate Fudge',
#   'Cake Fudge',
#   'Cake Fudge',
#   'Cafe Caramel',
#   'Hot Chocolate Fudge',
#   'Cake Fudge',
#   'Cake Fudge',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Death by Chocolate',
#   'Vanilla Double Scoop',
#   'Butterscotch Single Scoop',
#   'Hot Chocolate Fudge',
#   'Vanilla Single Scoop',
#   'Almond Fudge',
#   'Vanilla Double Scoop',
#   'Vanilla Single Scoop',
#   'Vanilla Double Scoop',
#   'Mint Fudge',
#   'Hot Chocolate Fudge',
#   'Cake Fudge',
#   'Vanilla Single Scoop',
#   'Mint Fudge',
#   'Cake Fudge',
#   'Cake Fudge',
#   'Cake Fudge',
#   'Vanilla Single Scoop',
#   'Butterscotch Single Scoop',
#   'Vanilla Double Scoop',
#   'Hot Chocolate Fudge',
#   'Cake Fudge',
#   'Cake Fudge',
#   'Vanilla Single Scoop',
#   'Butterscotch Single Scoop',
#   'Cake Fudge',
#   'Death by Chocolate',
#   'Butterscotch Single Scoop',
#   'Cake Fudge',
#   'Vanilla Double Scoop',
#   'Butterscotch Single Scoop',
#   'Vanilla Double Scoop',
#   'Vanilla Single Scoop',
#   'Vanilla Double Scoop',
#   'Hot Chocolate Fudge',
#   'Vanilla Double Scoop',
#   'Cake Fudge',
#   'Hot Chocolate Fudge',
#   'Fig and Honey Double Scoop',
#   'Dry Fruit Double Scoop',
#   'Vanilla Single Scoop',
#   'Cake Fudge',
#   'Vanilla Double Scoop',
#   'Death by Chocolate',
#   'Vanilla Single Scoop',
#   'Caramel Crunch Double Scoop',
#   'Butterscotch Single Scoop',
#   'Vanilla Single Scoop',
#   'Chocolate Europa Single Scoop',
#   'Hot Chocolate Fudge',
#   'Vanilla Double Scoop',
#   'Death by Chocolate',
#   'Cake Fudge',
#   'Trilogy',
#   'Hot Chocolate Fudge',
#   'Cafe Caramel',
#   'Vanilla Double Scoop',
#   'Hot Chocolate Fudge',
#   'Butterscotch Single Scoop',
#   'Death by Chocolate',
#   'Vanilla Single Scoop',
#   'Dry Fruit Double Scoop',
#   'Hot Chocolate Fudge',
#   'Butterscotch Single Scoop',
#   'Vanilla Single Scoop',
#   'Hot Chocolate Fudge',
#   'Cake Fudge',
#   'Vanilla Double Scoop',
#   'Dew Drop Sundae',
#   'Cake Fudge',
#   'Vanilla Double Scoop',
#   'Vanilla Single Scoop',
#   'Hot Chocolate Fudge',
#   'Vanilla Double Scoop',
#   'Cake Fudge',
#   'Vanilla Double Scoop',
#   'Cake Fudge',
#   'Caramel Crunch Single Scoop',
#   'Hot Chocolate Fudge',
#   'Cake Fudge',
#   'Butterscotch Double Scoop',
#   'Death by Chocolate',
#   'Vanilla Double Scoop',
#   'Almond Fudge',
#   'Fig and Honey Single Scoop',
#   'Cake Fudge',
#   'Cafe Caramel',
#   'Fig and Honey Double Scoop',
#   'Vanilla Double Scoop',
#   'Death by Chocolate',
#   'Vanilla Double Scoop',
#   'Cake Fudge',
#   'Cake Fudge',
#   'Cake Fudge',
#   'Cake Fudge',
#   'Death by Chocolate',
#   'Butterscotch Double Scoop',
#   'Vanilla Single Scoop',
#   'Pista Single Scoop',
#   'Cake Fudge',
#   'Vanilla Double Scoop',
#   'Butterscotch Single Scoop',
#   'Cake Fudge',
#   'Vanilla Single Scoop',
#   'Hot Chocolate Fudge',
#   'Vanilla Double Scoop',
#   'Vanilla Double Scoop',
#   'Butterscotch Single Scoop',
#   'Cafe Caramel',
#   'Cake Fudge',
#   'Death by Chocolate',
#   'Cake Fudge',
#   'Vanilla Single Scoop',
#   'Vanilla Double Scoop',
#   'Pista Single Scoop',
#   'Butterscotch Single Scoop',
#   'Caramel Crunch Single Scoop',
#   'Vanilla Double Scoop',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Vanilla Double Scoop',
#   'Vanilla Single Scoop',
#   'Cake Fudge',
#   'Cake Fudge',
#   'Vanilla Double Scoop',
#   'Chocolate Europa Double Scoop',
#   'Death by Chocolate',
#   'Butterscotch Double Scoop',
#   'Cafe Caramel',
#   'Cake Fudge',
#   'Butterscotch Single Scoop',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Vanilla Single Scoop',
#   'Hot Chocolate Fudge',
#   'Cake Fudge',
#   'Cafe Caramel',
#   'Hot Chocolate Fudge',
#   'Death by Chocolate',
#   'Death by Chocolate',
#   'Cafe Caramel',
#   'Hot Chocolate Fudge',
#   'Death by Chocolate',
#   'Vanilla Double Scoop',
#   'Butterscotch Single Scoop',
#   'Vanilla Single Scoop',
#   'Butterscotch Single Scoop',
#   'Vanilla Single Scoop',
#   'Vanilla Single Scoop',
#   'Hot Chocolate Fudge',
#   'Butterscotch Single Scoop',
#   'Vanilla Double Scoop',
#   'Cake Fudge',
#   'Cake Fudge',
#   'Hot Chocolate Fudge',
#   'Vanilla Double Scoop',
#   'Cake Fudge',
#   'Cake Fudge',
#   'Cake Fudge',
#   'Butterscotch Single Scoop',
#   'Death by Chocolate',
#   'Death by Chocolate',
#   'Cake Fudge',
#   'Hot Chocolate Fudge',
#   'Caramel Crunch Single Scoop',
#   'Cake Fudge',
#   'Vanilla Single Scoop',
#   'Butterscotch Single Scoop',
#   'Vanilla Single Scoop',
#   'Hot Chocolate Fudge',
#   'Butterscotch Single Scoop',
#   'Cake Fudge',
#   'Butterscotch Double Scoop',
#   'Death by Chocolate',
#   'Vanilla Single Scoop',
#   'Death by Chocolate',
#   'Death by Chocolate',
#   'Dry Fruit Double Scoop',
#   'Death by Chocolate',
#   'Butterscotch Single Scoop',
#   'Vanilla Double Scoop',
#   'Vanilla Double Scoop',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Death by Chocolate',
#   'Vanilla Single Scoop',
#   'Vanilla Double Scoop',
#   'Death by Chocolate',
#   'Vanilla Single Scoop',
#   'Vanilla Single Scoop',
#   'Chocolate Europa Double Scoop',
#   'Vanilla Double Scoop',
#   'Hot Chocolate Fudge',
#   'Cake Fudge',
#   'Hot Chocolate Fudge',
#   'Vanilla Double Scoop',
#   'Hot Chocolate Fudge',
#   'Vanilla Double Scoop',
#   'Rocky Road Single Scoop',
#   'Vanilla Double Scoop',
#   'Cafe Caramel',
#   'Caramel Crunch Single Scoop',
#   'Mint Fudge',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Caramel Crunch Double Scoop',
#   'Hot Chocolate Fudge',
#   'Cake Fudge',
#   'Cake Fudge',
#   'Vanilla Single Scoop',
#   'Cafe Caramel',
#   'Butterscotch Single Scoop',
#   'Cake Fudge',
#   'Death by Chocolate',
#   'Vanilla Single Scoop',
#   'Caramel Crunch Single Scoop',
#   'Vanilla Double Scoop',
#   'Butterscotch Single Scoop',
#   'Vanilla Double Scoop',
#   'Hot Chocolate Fudge',
#   'Vanilla Double Scoop',
#   'Rocky Road Single Scoop',
#   'Caramel Crunch Double Scoop',
#   'Death by Chocolate',
#   'Cake Fudge',
#   'Hot Chocolate Fudge',
#   'Vanilla Single Scoop',
#   'Butterscotch Double Scoop',
#   'Hot Chocolate Fudge',
#   'Butterscotch Single Scoop',
#   'Hot Chocolate Fudge',
#   'Vanilla Single Scoop',
#   'Hot Chocolate Fudge',
#   'Vanilla Single Scoop',
#   'Dry Fruit Single Scoop',
#   'Vanilla Double Scoop',
#   'Vanilla Single Scoop',
#   'Cake Fudge',
#   'Butterscotch Single Scoop',
#   'Hot Chocolate Fudge',
#   'Vanilla Single Scoop',
#   'Butterscotch Single Scoop',
#   'Pista Single Scoop',
#   'Butterscotch Single Scoop',
#   'Hot Chocolate Fudge',
#   'Death by Chocolate',
#   'Butterscotch Single Scoop',
#   'Vanilla Single Scoop',
#   'Hot Chocolate Fudge',
#   'Vanilla Single Scoop',
#   'Death by Chocolate',
#   'Butterscotch Single Scoop',
#   'Cafe Caramel',
#   'Vanilla Double Scoop',
#   'Cake Fudge',
#   'Cake Fudge',
#   'Vanilla Single Scoop',
#   'Dry Fruit Single Scoop',
#   'Vanilla Single Scoop',
#   'Cake Fudge',
#   'Vanilla Single Scoop',
#   'Butterscotch Single Scoop',
#   'Hot Chocolate Fudge',
#   'Cake Fudge',
#   'Cake Fudge',
#   'Butterscotch Single Scoop',
#   'Caramel Crunch Double Scoop',
#   'Vanilla Double Scoop',
#   'Butterscotch Single Scoop',
#   'Vanilla Single Scoop',
#   'Vanilla Single Scoop',
#   'Hot Chocolate Fudge',
#   'Cake Fudge',
#   'Vanilla Double Scoop',
#   'Pista Double Scoop',
#   'Caramel Crunch Single Scoop',
#   'Fig and Honey Double Scoop',
#   'Dew Drop Sundae',
#   'Vanilla Single Scoop',
#   'Cafe Caramel',
#   'Cake Fudge',
#   'Death by Chocolate',
#   'Cafe Caramel',
#   'Cake Fudge',
#   'Butterscotch Single Scoop',
#   'Pista Single Scoop',
#   'Vanilla Double Scoop',
#   'Pista Double Scoop',
#   'Hot Chocolate Fudge',
#   'Cake Fudge',
#   'Vanilla Double Scoop',
#   'Death by Chocolate',
#   'Hot Chocolate Fudge',
#   'Mint Fudge',
#   'Cake Fudge',
#   'Death by Chocolate',
#   'Vanilla Single Scoop',
#   'Butterscotch Single Scoop',
#   'Butterscotch Single Scoop',
#   'Cake Fudge',
#   'Cake Fudge',
#   'Hot Chocolate Fudge',
#   'Rocky Road Single Scoop',
#   'Cake Fudge',
#   'Vanilla Double Scoop',
#   'Vanilla Double Scoop',
#   'Rocky Road Single Scoop',
#   'Butterscotch Single Scoop',
#   'Pista Double Scoop',
#   'Cake Fudge',
#   'Vanilla Double Scoop',
#   'Death by Chocolate',
#   'Hot Chocolate Fudge',
#   'Vanilla Double Scoop',
#   'Death by Chocolate',
#   'Cafe Caramel',
#   'Mint Fudge',
#   'Vanilla Double Scoop',
#   'Cake Fudge',
#   'Cafe Caramel',
#   'Cake Fudge',
#   'Hot Chocolate Fudge',
#   'Fig and Honey Double Scoop',
#   'Vanilla Double Scoop',
#   'Vanilla Single Scoop',
#   'Butterscotch Single Scoop',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Vanilla Double Scoop',
#   'Vanilla Double Scoop',
#   'Almond Fudge',
#   'Butterscotch Single Scoop',
#   'Butterscotch Single Scoop',
#   'Chocolate Europa Double Scoop',
#   'Cake Fudge',
#   'Cake Fudge',
#   'Vanilla Single Scoop',
#   'Vanilla Double Scoop',
#   'Cafe Caramel',
#   'Vanilla Double Scoop',
#   'Vanilla Single Scoop',
#   'Butterscotch Single Scoop',
#   'Vanilla Double Scoop',
#   'Hot Chocolate Fudge',
#   'Death by Chocolate',
#   'Vanilla Double Scoop',
#   'Cake Fudge',
#   'Vanilla Double Scoop',
#   'Vanilla Double Scoop',
#   'Cake Fudge',
#   'Cake Fudge',
#   'Cafe Caramel',
#   'Cake Fudge',
#   'Vanilla Double Scoop',
#   'Hot Chocolate Fudge',
#   'Vanilla Single Scoop',
#   'Cake Fudge',
#   'Vanilla Single Scoop',
#   'Butterscotch Single Scoop',
#   'Cafe Caramel',
#   'Hot Chocolate Fudge',
#   'Almond Fudge',
#   'Vanilla Single Scoop',
#   'Cake Fudge',
#   'Vanilla Double Scoop',
#   'Vanilla Single Scoop',
#   'Chocolate Europa Single Scoop',
#   'Rocky Road Single Scoop',
#   'Vanilla Single Scoop',
#   'Cake Fudge',
#   'Dry Fruit Double Scoop',
#   'Hot Chocolate Fudge',
#   'Death by Chocolate',
#   'Mint Fudge',
#   'Death by Chocolate',
#   'Vanilla Double Scoop',
#   'Fig and Honey Double Scoop',
#   'Butterscotch Single Scoop',
#   'Pista Double Scoop',
#   'Cake Fudge',
#   'Fig and Honey Double Scoop',
#   'Fig and Honey Single Scoop',
#   'Butterscotch Single Scoop',
#   'Hot Chocolate Fudge',
#   'Rocky Road Single Scoop',
#   'Cafe Caramel',
#   'Chocolate Europa Single Scoop',
#   'Vanilla Double Scoop',
#   'Hot Chocolate Fudge',
#   'Cake Fudge',
#   'Butterscotch Single Scoop',
#   'Butterscotch Single Scoop',
#   'Cake Fudge',
#   'Caramel Crunch Single Scoop',
#   'Butterscotch Single Scoop',
#   'Butterscotch Double Scoop',
#   'Vanilla Single Scoop',
#   'Hot Chocolate Fudge',
#   'Vanilla Single Scoop',
#   'Vanilla Single Scoop',
#   'Vanilla Single Scoop',
#   'Butterscotch Single Scoop',
#   'Vanilla Double Scoop',
#   'Cafe Caramel',
#   'Butterscotch Single Scoop',
#   'Vanilla Double Scoop',
#   'Vanilla Double Scoop',
#   'Butterscotch Single Scoop',
#   'Vanilla Double Scoop',
#   'Hot Chocolate Fudge',
#   'Cake Fudge',
#   'Cake Fudge',
#   'Cafe Caramel',
#   'Vanilla Single Scoop',
#   'Pista Double Scoop',
#   'Death by Chocolate',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Vanilla Single Scoop',
#   'Hot Chocolate Fudge',
#   'Cake Fudge',
#   'Butterscotch Double Scoop',
#   'Chocolate Europa Double Scoop',
#   'Hot Chocolate Fudge',
#   'Fig and Honey Double Scoop',
#   'Vanilla Double Scoop',
#   'Cafe Caramel',
#   'Vanilla Single Scoop',
#   'Vanilla Double Scoop',
#   'Butterscotch Single Scoop',
#   'Vanilla Double Scoop',
#   'Butterscotch Single Scoop',
#   'Vanilla Double Scoop',
#   'Cake Fudge',
#   'Vanilla Double Scoop',
#   'Hot Chocolate Fudge',
#   'Hot Chocolate Fudge',
#   'Cake Fudge',
#   'Vanilla Single Scoop',
#   'Death by Chocolate',
#   ...],
#  'Unit Price': ['180',
#   '150',
#   '150',
#   '150',
#   '180',
#   '80',
#   '60',
#   '50',
#   '150',
#   '120',
#   '60',
#   '100',
#   '120',
#   '70',
#   '120',
#   '120',
#   '120',
#   '160',
#   '80',
#   '60',
#   '60',
#   '50',
#   '60',
#   '80',
#   '180',
#   '160',
#   '60',
#   '120',
#   '50',
#   '50',
#   '150',
#   '50',
#   '80',
#   '150',
#   '80',
#   '120',
#   '80',
#   '80',
#   '120',
#   '150',
#   '50',
#   '150',
#   '60',
#   '60',
#   '80',
#   '160',
#   '150',
#   '160',
#   '60',
#   '180',
#   '60',
#   '120',
#   '150',
#   '150',
#   '50',
#   '160',
#   '150',
#   '160',
#   '150',
#   '150',
#   '180',
#   '180',
#   '120',
#   '150',
#   '150',
#   '60',
#   '80',
#   '180',
#   '100',
#   '50',
#   '120',
#   '80',
#   '160',
#   '80',
#   '180',
#   '80',
#   '50',
#   '160',
#   '80',
#   '180',
#   '120',
#   '60',
#   '150',
#   '120',
#   '50',
#   '90',
#   '60',
#   '150',
#   '80',
#   '60',
#   '160',
#   '120',
#   '100',
#   '50',
#   '120',
#   '120',
#   '80',
#   '160',
#   '80',
#   '80',
#   '150',
#   '50',
#   '120',
#   '120',
#   '80',
#   '50',
#   '80',
#   '50',
#   '50',
#   '120',
#   '60',
#   '50',
#   '120',
#   '50',
#   '180',
#   '90',
#   '50',
#   '60',
#   '50',
#   '150',
#   '80',
#   '80',
#   '100',
#   '180',
#   '120',
#   '180',
#   '150',
#   '160',
#   '90',
#   '150',
#   '50',
#   '180',
#   '150',
#   '120',
#   '70',
#   '60',
#   '90',
#   '120',
#   '120',
#   '60',
#   '60',
#   '150',
#   '50',
#   '90',
#   '100',
#   '80',
#   '180',
#   '90',
#   '80',
#   '120',
#   '120',
#   '150',
#   '160',
#   '160',
#   '80',
#   '60',
#   '120',
#   '120',
#   '120',
#   '60',
#   '60',
#   '180',
#   '120',
#   '180',
#   '140',
#   '120',
#   '150',
#   '60',
#   '100',
#   '140',
#   '180',
#   '150',
#   '120',
#   '80',
#   '150',
#   '80',
#   '120',
#   '80',
#   '180',
#   '80',
#   '120',
#   '180',
#   '140',
#   '120',
#   '120',
#   '60',
#   '180',
#   '60',
#   '60',
#   '180',
#   '180',
#   '180',
#   '180',
#   '120',
#   '80',
#   '160',
#   '150',
#   '80',
#   '180',
#   '50',
#   '180',
#   '160',
#   '60',
#   '60',
#   '80',
#   '150',
#   '80',
#   '160',
#   '90',
#   '120',
#   '50',
#   '120',
#   '180',
#   '50',
#   '80',
#   '180',
#   '120',
#   '120',
#   '150',
#   '50',
#   '60',
#   '120',
#   '60',
#   '50',
#   '180',
#   '60',
#   '120',
#   '50',
#   '120',
#   '60',
#   '150',
#   '50',
#   '80',
#   '80',
#   '90',
#   '180',
#   '180',
#   '120',
#   '150',
#   '80',
#   '150',
#   '150',
#   '80',
#   '140',
#   '70',
#   '160',
#   '120',
#   '120',
#   '180',
#   '80',
#   '160',
#   '160',
#   '60',
#   '80',
#   '120',
#   '140',
#   '60',
#   '120',
#   '60',
#   '80',
#   '80',
#   '150',
#   '120',
#   '80',
#   '150',
#   '90',
#   '120',
#   '180',
#   '120',
#   '50',
#   '180',
#   '50',
#   '90',
#   '120',
#   '80',
#   '160',
#   '80',
#   '60',
#   '80',
#   '150',
#   '80',
#   '180',
#   '150',
#   '120',
#   '80',
#   '120',
#   '80',
#   '160',
#   '120',
#   '160',
#   '80',
#   '80',
#   '60',
#   '50',
#   '80',
#   '160',
#   '150',
#   '80',
#   '120',
#   '120',
#   '120',
#   '120',
#   '120',
#   '50',
#   '180',
#   '100',
#   '60',
#   '160',
#   '120',
#   '120',
#   '150',
#   '60',
#   '80',
#   '120',
#   '50',
#   '120',
#   '60',
#   '180',
#   '50',
#   '150',
#   '150',
#   '120',
#   '180',
#   '80',
#   '50',
#   '80',
#   '180',
#   '120',
#   '60',
#   '80',
#   '60',
#   '80',
#   '60',
#   '80',
#   '120',
#   '90',
#   '120',
#   '80',
#   '160',
#   '60',
#   '50',
#   '180',
#   '80',
#   '50',
#   '50',
#   '60',
#   '120',
#   '80',
#   '120',
#   '50',
#   '150',
#   '120',
#   '150',
#   '120',
#   '50',
#   '100',
#   '60',
#   '60',
#   '120',
#   '90',
#   '80',
#   '80',
#   '120',
#   '120',
#   '120',
#   '60',
#   '80',
#   '90',
#   '80',
#   '150',
#   '150',
#   '120',
#   '60',
#   '180',
#   '60',
#   '50',
#   '80',
#   '150',
#   '80',
#   '150',
#   '120',
#   '80',
#   '180',
#   '80',
#   '50',
#   '150',
#   '70',
#   '180',
#   '120',
#   '150',
#   '60',
#   '80',
#   '90',
#   '80',
#   '90',
#   '150',
#   '60',
#   '80',
#   '90',
#   '80',
#   '120',
#   '120',
#   '120',
#   '50',
#   '80',
#   '180',
#   '150',
#   '80',
#   '50',
#   '120',
#   '80',
#   '120',
#   '80',
#   '150',
#   '60',
#   '150',
#   '50',
#   '160',
#   '120',
#   '120',
#   '120',
#   '120',
#   '80',
#   '120',
#   '60',
#   '90',
#   '150',
#   '120',
#   '50',
#   '80',
#   '160',
#   '120',
#   '60',
#   '120',
#   '60',
#   '160',
#   '120',
#   '80',
#   '120',
#   '60',
#   '80',
#   '70',
#   '80',
#   '120',
#   '180',
#   '120',
#   '70',
#   '120',
#   '180',
#   '120',
#   '120',
#   '50',
#   '120',
#   '60',
#   '50',
#   '80',
#   '80',
#   '90',
#   '180',
#   '50',
#   '160',
#   '120',
#   '120',
#   '150',
#   '50',
#   '60',
#   '80',
#   '150',
#   '120',
#   '50',
#   '50',
#   '150',
#   '150',
#   '80',
#   '150',
#   '160',
#   '180',
#   '90',
#   '180',
#   '120',
#   '80',
#   '120',
#   '150',
#   '60',
#   '150',
#   '120',
#   '120',
#   '120',
#   '80',
#   '160',
#   '150',
#   '80',
#   '100',
#   '60',
#   '80',
#   '150',
#   '50',
#   '80',
#   '120',
#   '180',
#   '60',
#   '150',
#   '150',
#   '120',
#   '150',
#   '150',
#   '120',
#   '120',
#   '120',
#   '120',
#   '60',
#   '60',
#   '80',
#   '80',
#   '120',
#   '120',
#   '50',
#   '90',
#   '120',
#   '60',
#   '120',
#   '100',
#   '120',
#   '180',
#   '120',
#   '100',
#   '120',
#   '60',
#   '150',
#   '120',
#   '60',
#   '180',
#   '120',
#   '90',
#   '160',
#   '120',
#   '60',
#   '150',
#   '60',
#   '180',
#   '90',
#   '120',
#   '50',
#   '80',
#   '150',
#   '80',
#   '160',
#   '120',
#   '120',
#   '150',
#   '120',
#   '150',
#   '150',
#   '160',
#   '120',
#   '150',
#   '150',
#   '120',
#   '120',
#   '180',
#   '80',
#   '60',
#   '120',
#   '50',
#   '150',
#   '80',
#   '50',
#   '80',
#   '120',
#   '120',
#   '150',
#   '50',
#   '120',
#   '150',
#   '150',
#   '150',
#   '50',
#   '60',
#   '80',
#   '120',
#   '150',
#   '150',
#   '50',
#   '60',
#   '150',
#   '180',
#   '60',
#   '150',
#   '80',
#   '60',
#   '80',
#   '50',
#   '80',
#   '120',
#   '80',
#   '150',
#   '120',
#   '90',
#   '90',
#   '50',
#   '150',
#   '80',
#   '180',
#   '50',
#   '100',
#   '60',
#   '50',
#   '70',
#   '120',
#   '80',
#   '180',
#   '150',
#   '160',
#   '120',
#   '160',
#   '80',
#   '120',
#   '60',
#   '180',
#   '50',
#   '90',
#   '120',
#   '60',
#   '50',
#   '120',
#   '150',
#   '80',
#   '150',
#   '150',
#   '80',
#   '50',
#   '120',
#   '80',
#   '150',
#   '80',
#   '150',
#   '70',
#   '120',
#   '150',
#   '90',
#   '180',
#   '80',
#   '150',
#   '60',
#   '150',
#   '160',
#   '90',
#   '80',
#   '180',
#   '80',
#   '150',
#   '150',
#   '150',
#   '150',
#   '180',
#   '90',
#   '50',
#   '60',
#   '150',
#   '80',
#   '60',
#   '150',
#   '50',
#   '120',
#   '80',
#   '80',
#   '60',
#   '160',
#   '150',
#   '180',
#   '150',
#   '50',
#   '80',
#   '60',
#   '60',
#   '70',
#   '80',
#   '120',
#   '120',
#   '80',
#   '50',
#   '150',
#   '150',
#   '80',
#   '100',
#   '180',
#   '90',
#   '160',
#   '150',
#   '60',
#   '120',
#   '120',
#   '120',
#   '50',
#   '120',
#   '150',
#   '160',
#   '120',
#   '180',
#   '180',
#   '160',
#   '120',
#   '180',
#   '80',
#   '60',
#   '50',
#   '60',
#   '50',
#   '50',
#   '120',
#   '60',
#   '80',
#   '150',
#   '150',
#   '120',
#   '80',
#   '150',
#   '150',
#   '150',
#   '60',
#   '180',
#   '180',
#   '150',
#   '120',
#   '70',
#   '150',
#   '50',
#   '60',
#   '50',
#   '120',
#   '60',
#   '150',
#   '90',
#   '180',
#   '50',
#   '180',
#   '180',
#   '90',
#   '180',
#   '60',
#   '80',
#   '80',
#   '120',
#   '120',
#   '180',
#   '50',
#   '80',
#   '180',
#   '50',
#   '50',
#   '100',
#   '80',
#   '120',
#   '150',
#   '120',
#   '80',
#   '120',
#   '80',
#   '50',
#   '80',
#   '160',
#   '70',
#   '120',
#   '120',
#   '120',
#   '100',
#   '120',
#   '150',
#   '150',
#   '50',
#   '160',
#   '60',
#   '150',
#   '180',
#   '50',
#   '70',
#   '80',
#   '60',
#   '80',
#   '120',
#   '80',
#   '50',
#   '100',
#   '180',
#   '150',
#   '120',
#   '50',
#   '90',
#   '120',
#   '60',
#   '120',
#   '50',
#   '120',
#   '50',
#   '60',
#   '80',
#   '50',
#   '150',
#   '60',
#   '120',
#   '50',
#   '60',
#   '60',
#   '60',
#   '120',
#   '180',
#   '60',
#   '50',
#   '120',
#   '50',
#   '180',
#   '60',
#   '160',
#   '80',
#   '150',
#   '150',
#   '50',
#   '60',
#   '50',
#   '150',
#   '50',
#   '60',
#   '120',
#   '150',
#   '150',
#   '60',
#   '100',
#   '80',
#   '60',
#   '50',
#   '50',
#   '120',
#   '150',
#   '80',
#   '90',
#   '70',
#   '90',
#   '150',
#   '50',
#   '160',
#   '150',
#   '180',
#   '160',
#   '150',
#   '60',
#   '60',
#   '80',
#   '90',
#   '120',
#   '150',
#   '80',
#   '180',
#   '120',
#   '120',
#   '150',
#   '180',
#   '50',
#   '60',
#   '60',
#   '150',
#   '150',
#   '120',
#   '50',
#   '150',
#   '80',
#   '80',
#   '50',
#   '60',
#   '90',
#   '150',
#   '80',
#   '180',
#   '120',
#   '80',
#   '180',
#   '160',
# ...
#   '50',
#   '180',
#   ...],
#  'Quantity': ['5',
#   '1',
#   '1',
#   '3',
#   '1',
#   '3',
#   '5',
#   '5',
#   '5',
#   '3',
#   '5',
#   '1',
#   '2',
#   '4',
#   '2',
#   '4',
#   '2',
#   '5',
#   '4',
#   '3',
#   '3',
#   '2',
#   '3',
#   '1',
#   '2',
#   '2',
#   '3',
#   '2',
#   '3',
#   '5',
#   '1',
#   '4',
#   '3',
#   '1',
#   '5',
#   '5',
#   '2',
#   '3',
#   '5',
#   '5',
#   '5',
#   '5',
#   '1',
#   '2',
#   '1',
#   '1',
#   '5',
#   '5',
#   '3',
#   '2',
#   '1',
#   '3',
#   '2',
#   '2',
#   '4',
#   '1',
#   '5',
#   '5',
#   '1',
#   '1',
#   '5',
#   '5',
#   '4',
#   '2',
#   '4',
#   '5',
#   '4',
#   '2',
#   '5',
#   '3',
#   '1',
#   '3',
#   '1',
#   '4',
#   '3',
#   '5',
#   '1',
#   '3',
#   '4',
#   '2',
#   '5',
#   '2',
#   '2',
#   '2',
#   '5',
#   '3',
#   '3',
#   '2',
#   '5',
#   '1',
#   '5',
#   '4',
#   '4',
#   '1',
#   '4',
#   '3',
#   '3',
#   '2',
#   '1',
#   '5',
#   '3',
#   '5',
#   '2',
#   '5',
#   '2',
#   '4',
#   '5',
#   '4',
#   '4',
#   '3',
#   '3',
#   '2',
#   '4',
#   '3',
#   '2',
#   '2',
#   '1',
#   '3',
#   '3',
#   '2',
#   '2',
#   '5',
#   '4',
#   '4',
#   '1',
#   '2',
#   '2',
#   '2',
#   '1',
#   '2',
#   '2',
#   '1',
#   '3',
#   '4',
#   '5',
#   '5',
#   '2',
#   '1',
#   '2',
#   '4',
#   '3',
#   '3',
#   '4',
#   '1',
#   '5',
#   '4',
#   '1',
#   '5',
#   '4',
#   '2',
#   '5',
#   '3',
#   '1',
#   '1',
#   '3',
#   '2',
#   '5',
#   '1',
#   '1',
#   '4',
#   '5',
#   '4',
#   '1',
#   '2',
#   '3',
#   '2',
#   '1',
#   '2',
#   '2',
#   '5',
#   '2',
#   '4',
#   '3',
#   '3',
#   '3',
#   '4',
#   '3',
#   '3',
#   '3',
#   '1',
#   '4',
#   '2',
#   '3',
#   '2',
#   '5',
#   '4',
#   '1',
#   '4',
#   '2',
#   '4',
#   '3',
#   '3',
#   '4',
#   '3',
#   '3',
#   '1',
#   '5',
#   '5',
#   '5',
#   '5',
#   '5',
#   '4',
#   '1',
#   '3',
#   '4',
#   '1',
#   '2',
#   '5',
#   '3',
#   '1',
#   '2',
#   '4',
#   '4',
#   '5',
#   '4',
#   '4',
#   '3',
#   '3',
#   '4',
#   '5',
#   '3',
#   '5',
#   '4',
#   '4',
#   '5',
#   '5',
#   '1',
#   '5',
#   '2',
#   '5',
#   '2',
#   '4',
#   '4',
#   '2',
#   '2',
#   '5',
#   '3',
#   '4',
#   '5',
#   '2',
#   '5',
#   '1',
#   '2',
#   '5',
#   '1',
#   '5',
#   '3',
#   '4',
#   '2',
#   '5',
#   '3',
#   '5',
#   '4',
#   '3',
#   '1',
#   '3',
#   '3',
#   '5',
#   '3',
#   '5',
#   '4',
#   '2',
#   '5',
#   '3',
#   '1',
#   '2',
#   '1',
#   '1',
#   '4',
#   '3',
#   '5',
#   '4',
#   '4',
#   '4',
#   '4',
#   '4',
#   '5',
#   '5',
#   '2',
#   '5',
#   '1',
#   '1',
#   '2',
#   '3',
#   '3',
#   '2',
#   '5',
#   '3',
#   '4',
#   '1',
#   '1',
#   '4',
#   '5',
#   '4',
#   '4',
#   '5',
#   '5',
#   '1',
#   '5',
#   '4',
#   '2',
#   '4',
#   '5',
#   '1',
#   '2',
#   '2',
#   '5',
#   '1',
#   '2',
#   '3',
#   '2',
#   '4',
#   '1',
#   '3',
#   '5',
#   '4',
#   '1',
#   '4',
#   '4',
#   '2',
#   '1',
#   '2',
#   '1',
#   '3',
#   '4',
#   '3',
#   '5',
#   '3',
#   '5',
#   '3',
#   '4',
#   '3',
#   '2',
#   '4',
#   '2',
#   '3',
#   '5',
#   '3',
#   '5',
#   '2',
#   '2',
#   '1',
#   '4',
#   '5',
#   '4',
#   '3',
#   '2',
#   '4',
#   '4',
#   '2',
#   '4',
#   '3',
#   '2',
#   '1',
#   '3',
#   '4',
#   '1',
#   '3',
#   '2',
#   '3',
#   '1',
#   '3',
#   '3',
#   '5',
#   '1',
#   '5',
#   '2',
#   '1',
#   '3',
#   '2',
#   '2',
#   '4',
#   '4',
#   '5',
#   '3',
#   '5',
#   '5',
#   '4',
#   '4',
#   '4',
#   '3',
#   '1',
#   '4',
#   '4',
#   '4',
#   '5',
#   '5',
#   '2',
#   '2',
#   '5',
#   '2',
#   '3',
#   '2',
#   '2',
#   '5',
#   '3',
#   '1',
#   '3',
#   '1',
#   '5',
#   '2',
#   '1',
#   '3',
#   '4',
#   '3',
#   '5',
#   '1',
#   '5',
#   '4',
#   '3',
#   '3',
#   '5',
#   '1',
#   '4',
#   '3',
#   '4',
#   '4',
#   '5',
#   '1',
#   '3',
#   '2',
#   '5',
#   '5',
#   '4',
#   '1',
#   '5',
#   '2',
#   '1',
#   '4',
#   '1',
#   '1',
#   '5',
#   '4',
#   '4',
#   '5',
#   '3',
#   '1',
#   '2',
#   '5',
#   '3',
#   '5',
#   '5',
#   '5',
#   '1',
#   '4',
#   '2',
#   '5',
#   '1',
#   '2',
#   '3',
#   '2',
#   '1',
#   '3',
#   '5',
#   '1',
#   '1',
#   '2',
#   '1',
#   '1',
#   '5',
#   '5',
#   '2',
#   '3',
#   '2',
#   '2',
#   '4',
#   '5',
#   '3',
#   '5',
#   '2',
#   '5',
#   '4',
#   '2',
#   '2',
#   '4',
#   '3',
#   '5',
#   '2',
#   '1',
#   '5',
#   '3',
#   '2',
#   '2',
#   '5',
#   '4',
#   '1',
#   '3',
#   '3',
#   '5',
#   '4',
#   '1',
#   '3',
#   '5',
#   '5',
#   '5',
#   '2',
#   '1',
#   '5',
#   '2',
#   '5',
#   '4',
#   '1',
#   '4',
#   '4',
#   '1',
#   '5',
#   '3',
#   '4',
#   '3',
#   '4',
#   '4',
#   '3',
#   '3',
#   '3',
#   '5',
#   '3',
#   '4',
#   '3',
#   '4',
#   '4',
#   '3',
#   '5',
#   '1',
#   '5',
#   '1',
#   '1',
#   '5',
#   '4',
#   '1',
#   '3',
#   '2',
#   '1',
#   '3',
#   '5',
#   '5',
#   '5',
#   '5',
#   '2',
#   '2',
#   '1',
#   '3',
#   '3',
#   '2',
#   '1',
#   '2',
#   '3',
#   '5',
#   '3',
#   '3',
#   '2',
#   '4',
#   '3',
#   '1',
#   '1',
#   '5',
#   '5',
#   '4',
#   '5',
#   '2',
#   '2',
#   '3',
#   '4',
#   '1',
#   '3',
#   '5',
#   '2',
#   '2',
#   '2',
#   '4',
#   '2',
#   '4',
#   '2',
#   '3',
#   '1',
#   '2',
#   '4',
#   '3',
#   '4',
#   '4',
#   '2',
#   '2',
#   '3',
#   '1',
#   '4',
#   '1',
#   '1',
#   '5',
#   '1',
#   '1',
#   '4',
#   '5',
#   '3',
#   '4',
#   '4',
#   '1',
#   '5',
#   '2',
#   '5',
#   '4',
#   '4',
#   '3',
#   '4',
#   '3',
#   '3',
#   '3',
#   '3',
#   '3',
#   '4',
#   '3',
#   '4',
#   '2',
#   '1',
#   '1',
#   '3',
#   '1',
#   '5',
#   '3',
#   '5',
#   '2',
#   '5',
#   '5',
#   '1',
#   '2',
#   '2',
#   '3',
#   '3',
#   '1',
#   '5',
#   '3',
#   '4',
#   '5',
#   '1',
#   '3',
#   '4',
#   '1',
#   '5',
#   '2',
#   '4',
#   '4',
#   '3',
#   '1',
#   '5',
#   '2',
#   '3',
#   '4',
#   '4',
#   '3',
#   '1',
#   '3',
#   '2',
#   '4',
#   '1',
#   '1',
#   '2',
#   '4',
#   '2',
#   '5',
#   '2',
#   '4',
#   '3',
#   '4',
#   '5',
#   '5',
#   '4',
#   '5',
#   '4',
#   '5',
#   '3',
#   '2',
#   '3',
#   '5',
#   '2',
#   '1',
#   '3',
#   '5',
#   '5',
#   '3',
#   '1',
#   '2',
#   '3',
#   '1',
#   '3',
#   '2',
#   '1',
#   '3',
#   '1',
#   '5',
#   '5',
#   '1',
#   '4',
#   '2',
#   '3',
#   '2',
#   '1',
#   '1',
#   '3',
#   '3',
#   '3',
#   '1',
#   '3',
#   '5',
#   '1',
#   '2',
#   '1',
#   '3',
#   '3',
#   '1',
#   '3',
#   '5',
#   '4',
#   '4',
#   '3',
#   '1',
#   '5',
#   '1',
#   '4',
#   '3',
#   '3',
#   '2',
#   '2',
#   '5',
#   '4',
#   '1',
#   '2',
#   '4',
#   '2',
#   '4',
#   '3',
#   '2',
#   '1',
#   '3',
#   '1',
#   '4',
#   '1',
#   '4',
#   '5',
#   '1',
#   '4',
#   '5',
#   '5',
#   '1',
#   '4',
#   '2',
#   '1',
#   '2',
#   '2',
#   '3',
#   '5',
#   '4',
#   '3',
#   '4',
#   '1',
#   '5',
#   '3',
#   '3',
#   '5',
#   '4',
#   '4',
#   '3',
#   '4',
#   '4',
#   '1',
#   '3',
#   '1',
#   '2',
#   '3',
#   '5',
#   '1',
#   '2',
#   '2',
#   '5',
#   '4',
#   '4',
#   '4',
#   '4',
#   '1',
#   '5',
#   '4',
#   '4',
#   '1',
#   '2',
#   '2',
#   '3',
#   '1',
#   '1',
#   '5',
#   '3',
#   '3',
#   '3',
#   '3',
#   '4',
#   '4',
#   '3',
#   '4',
#   '1',
#   '5',
#   '5',
#   '1',
#   '3',
#   '4',
#   '1',
#   '3',
#   '1',
#   '4',
#   '5',
#   '4',
#   '2',
#   '4',
#   '3',
#   '3',
#   '4',
#   '5',
#   '1',
#   '3',
#   '5',
#   '1',
#   '4',
#   '5',
#   '2',
#   '3',
#   '3',
#   '4',
#   '5',
#   '2',
#   '2',
#   '3',
#   '2',
#   '5',
#   '4',
#   '5',
#   '3',
#   '5',
#   '2',
#   '3',
#   '3',
#   '4',
#   '3',
#   '2',
#   '5',
#   '1',
#   '5',
#   '4',
#   '1',
#   '4',
#   '5',
#   '1',
#   '4',
#   '2',
#   '3',
#   '5',
#   '4',
#   '4',
#   '3',
#   '2',
#   '4',
#   '4',
#   '1',
#   '2',
#   '1',
#   '3',
#   '4',
#   '1',
#   '1',
#   '5',
#   '5',
#   '3',
#   '5',
#   '4',
#   '3',
#   '1',
#   '5',
#   '1',
#   '4',
#   '1',
#   '4',
#   '1',
#   '5',
#   '3',
#   '2',
#   '4',
#   '3',
#   '5',
#   '1',
#   '1',
#   '4',
#   '2',
#   '5',
#   '3',
#   '4',
#   '3',
#   '1',
#   '5',
#   '5',
#   '3',
#   '4',
#   '1',
#   '2',
#   '4',
#   '4',
#   '3',
#   '5',
#   '1',
#   '3',
#   '4',
#   '2',
#   '5',
#   '5',
#   '5',
#   '1',
#   '1',
#   '1',
#   '1',
#   '5',
#   '5',
#   '2',
#   '3',
#   '3',
#   '5',
#   '3',
#   '2',
#   '3',
#   '4',
#   '3',
#   '3',
#   '1',
#   '4',
#   '3',
#   '1',
#   '3',
#   '2',
#   '4',
#   '2',
#   '2',
#   '4',
#   '1',
#   '5',
#   '4',
#   '4',
#   '5',
#   '1',
#   '2',
#   '2',
#   '3',
#   '1',
#   '5',
#   '4',
#   '2',
#   '5',
#   '3',
#   '3',
#   '1',
#   '1',
#   '2',
#   '5',
#   '4',
#   '2',
#   '5',
#   '4',
#   '3',
#   '4',
#   '2',
#   '2',
#   '5',
#   '1',
#   '4',
#   '4',
#   '5',
#   '1',
#   '5',
#   '5',
#   '3',
#   '5',
#   '2',
#   '1',
#   '1',
#   '4',
#   '5',
#   '4',
#   '1',
#   '2',
#   '3',
#   '3',
#   '1',
#   '4',
#   '3',
#   '4',
#   '4',
#   '1',
#   '4',
#   '4',
#   '4',
#   '3',
#   '4',
#   '4',
#   '4',
#   '2',
#   '5',
#   '3',
#   '2',
#   '5',
#   ...],
#  'Total Price': ['900',
#   '150',
#   '150',
#   '450',
#   '180',
#   '240',
#   '300',
#   '250',
#   '750',
#   '360',
#   '300',
#   '100',
#   '240',
#   '280',
#   '240',
#   '480',
#   '240',
#   '800',
#   '320',
#   '180',
#   '180',
#   '100',
#   '180',
#   '80',
#   '360',
#   '320',
#   '180',
#   '240',
#   '150',
#   '250',
#   '150',
#   '200',
#   '240',
#   '150',
#   '400',
#   '600',
#   '160',
#   '240',
#   '600',
#   '750',
#   '250',
#   '750',
#   '60',
#   '120',
#   '80',
#   '160',
#   '750',
#   '800',
#   '180',
#   '360',
#   '60',
#   '360',
#   '300',
#   '300',
#   '200',
#   '160',
#   '750',
#   '800',
#   '150',
#   '150',
#   '900',
#   '900',
#   '480',
#   '300',
#   '600',
#   '300',
#   '320',
#   '360',
#   '500',
#   '150',
#   '120',
#   '240',
#   '160',
#   '320',
#   '540',
#   '400',
#   '50',
#   '480',
#   '320',
#   '360',
#   '600',
#   '120',
#   '300',
#   '240',
#   '250',
#   '270',
#   '180',
#   '300',
#   '400',
#   '60',
#   '800',
#   '480',
#   '400',
#   '50',
#   '480',
#   '360',
#   '240',
#   '320',
#   '80',
#   '400',
#   '450',
#   '250',
#   '240',
#   '600',
#   '160',
#   '200',
#   '400',
#   '200',
#   '200',
#   '360',
#   '180',
#   '100',
#   '480',
#   '150',
#   '360',
#   '180',
#   '50',
#   '180',
#   '150',
#   '300',
#   '160',
#   '400',
#   '400',
#   '720',
#   '120',
#   '360',
#   '300',
#   '320',
#   '90',
#   '300',
#   '100',
#   '180',
#   '450',
#   '480',
#   '350',
#   '300',
#   '180',
#   '120',
#   '240',
#   '240',
#   '180',
#   '450',
#   '200',
#   '90',
#   '500',
#   '320',
#   '180',
#   '450',
#   '320',
#   '240',
#   '600',
#   '450',
#   '160',
#   '160',
#   '240',
#   '120',
#   '600',
#   '120',
#   '120',
#   '240',
#   '300',
#   '720',
#   '120',
#   '360',
#   '420',
#   '240',
#   '150',
#   '120',
#   '200',
#   '700',
#   '360',
#   '600',
#   '360',
#   '240',
#   '450',
#   '320',
#   '360',
#   '240',
#   '540',
#   '80',
#   '480',
#   '360',
#   '420',
#   '240',
#   '600',
#   '240',
#   '180',
#   '240',
#   '120',
#   '720',
#   '540',
#   '540',
#   '720',
#   '360',
#   '240',
#   '160',
#   '750',
#   '400',
#   '900',
#   '250',
#   '900',
#   '640',
#   '60',
#   '180',
#   '320',
#   '150',
#   '160',
#   '800',
#   '270',
#   '120',
#   '100',
#   '480',
#   '720',
#   '250',
#   '320',
#   '720',
#   '360',
#   '360',
#   '600',
#   '250',
#   '180',
#   '600',
#   '240',
#   '200',
#   '900',
#   '300',
#   '120',
#   '250',
#   '240',
#   '300',
#   '300',
#   '200',
#   '320',
#   '160',
#   '180',
#   '900',
#   '540',
#   '480',
#   '750',
#   '160',
#   '750',
#   '150',
#   '160',
#   '700',
#   '70',
#   '800',
#   '360',
#   '480',
#   '360',
#   '400',
#   '480',
#   '800',
#   '240',
#   '240',
#   '120',
#   '420',
#   '180',
#   '600',
#   '180',
#   '400',
#   '320',
#   '300',
#   '600',
#   '240',
#   '150',
#   '180',
#   '120',
#   '180',
#   '480',
#   '150',
#   '900',
#   '200',
#   '360',
#   '480',
#   '320',
#   '640',
#   '400',
#   '300',
#   '160',
#   '750',
#   '80',
#   '180',
#   '300',
#   '360',
#   '240',
#   '240',
#   '400',
#   '480',
#   '480',
#   '160',
#   '80',
#   '320',
#   '300',
#   '200',
#   '320',
#   '800',
#   '750',
#   '80',
#   '600',
#   '480',
#   '240',
#   '480',
#   '600',
#   '50',
#   '360',
#   '200',
#   '300',
#   '160',
#   '240',
#   '360',
#   '300',
#   '240',
#   '80',
#   '360',
#   '250',
#   '480',
#   '60',
#   '720',
#   '200',
#   '300',
#   '150',
#   '240',
#   '180',
#   '240',
#   '200',
#   '240',
#   '900',
#   '360',
#   '300',
#   '240',
#   '240',
#   '240',
#   '120',
#   '320',
#   '240',
#   '270',
#   '600',
#   '240',
#   '800',
#   '120',
#   '100',
#   '180',
#   '320',
#   '250',
#   '200',
#   '180',
#   '240',
#   '320',
#   '480',
#   '100',
#   '600',
#   '360',
#   '300',
#   '120',
#   '150',
#   '400',
#   '60',
#   '180',
#   '240',
#   '270',
#   '80',
#   '240',
#   '360',
#   '600',
#   '120',
#   '300',
#   '160',
#   '90',
#   '240',
#   '300',
#   '300',
#   '480',
#   '240',
#   '900',
#   '180',
#   '250',
#   '400',
#   '600',
#   '320',
#   '600',
#   '360',
#   '80',
#   '720',
#   '320',
#   '200',
#   '750',
#   '350',
#   '360',
#   '240',
#   '750',
#   '120',
#   '240',
#   '180',
#   '160',
#   '450',
#   '450',
#   '60',
#   '240',
#   '90',
#   '400',
#   '240',
#   '120',
#   '360',
#   '200',
#   '240',
#   '900',
#   '150',
#   '400',
#   '200',
#   '360',
#   '240',
#   '600',
#   '80',
#   '600',
#   '180',
#   '600',
#   '200',
#   '800',
#   '120',
#   '360',
#   '240',
#   '600',
#   '400',
#   '480',
#   '60',
#   '450',
#   '300',
#   '120',
#   '200',
#   '80',
#   '160',
#   '600',
#   '240',
#   '480',
#   '300',
#   '480',
#   '120',
#   '160',
#   '600',
#   '180',
#   '400',
#   '350',
#   '400',
#   '120',
#   '720',
#   '240',
#   '350',
#   '120',
#   '360',
#   '360',
#   '240',
#   '50',
#   '360',
#   '300',
#   '50',
#   '80',
#   '160',
#   '90',
#   '180',
#   '250',
#   '800',
#   '240',
#   '360',
#   '300',
#   '100',
#   '240',
#   '400',
#   '450',
#   '600',
#   '100',
#   '250',
#   '600',
#   '300',
#   '160',
#   '600',
#   '480',
#   '900',
#   '180',
#   '180',
#   '600',
#   '240',
#   '240',
#   '300',
#   '300',
#   '600',
#   '120',
#   '360',
#   '360',
#   '400',
#   '640',
#   '150',
#   '240',
#   '500',
#   '300',
#   '400',
#   '300',
#   '50',
#   '400',
#   '240',
#   '900',
#   '240',
#   '150',
#   '600',
#   '480',
#   '150',
#   '750',
#   '360',
#   '480',
#   '360',
#   '480',
#   '240',
#   '180',
#   '240',
#   '240',
#   '600',
#   '360',
#   '200',
#   '270',
#   '480',
#   '240',
#   '360',
#   '500',
#   '120',
#   '900',
#   '120',
#   '100',
#   '600',
#   '240',
#   '150',
#   '360',
#   '120',
#   '180',
#   '360',
#   '450',
#   '800',
#   '600',
#   '300',
#   '300',
#   '120',
#   '180',
#   '270',
#   '360',
#   '100',
#   '80',
#   '300',
#   '240',
#   '800',
#   '360',
#   '360',
#   '300',
#   '480',
#   '450',
#   '150',
#   '160',
#   '600',
#   '750',
#   '600',
#   '600',
#   '240',
#   '360',
#   '240',
#   '240',
#   '120',
#   '150',
#   '750',
#   '160',
#   '100',
#   '160',
#   '480',
#   '240',
#   '600',
#   '100',
#   '360',
#   '150',
#   '300',
#   '600',
#   '150',
#   '240',
#   '320',
#   '240',
#   '300',
#   '450',
#   '50',
#   '240',
#   '150',
#   '180',
#   '300',
#   '150',
#   '80',
#   '240',
#   '400',
#   '150',
#   '320',
#   '480',
#   '80',
#   '750',
#   '240',
#   '450',
#   '360',
#   '200',
#   '450',
#   '320',
#   '540',
#   '150',
#   '300',
#   '180',
#   '150',
#   '280',
#   '360',
#   '320',
#   '360',
#   '150',
#   '160',
#   '360',
#   '160',
#   '400',
#   '360',
#   '300',
#   '360',
#   '250',
#   '450',
#   '120',
#   '120',
#   '100',
#   '360',
#   '450',
#   '80',
#   '750',
#   '450',
#   '320',
#   '250',
#   '120',
#   '240',
#   '600',
#   '80',
#   '750',
#   '140',
#   '480',
#   '600',
#   '270',
#   '180',
#   '400',
#   '300',
#   '180',
#   '600',
#   '640',
#   '270',
#   '80',
#   '540',
#   '160',
#   '600',
#   '150',
#   '150',
#   '300',
#   '720',
#   '180',
#   '250',
#   '120',
#   '600',
#   '240',
#   '240',
#   '750',
#   '250',
#   '480',
#   '400',
#   '320',
#   '300',
#   '480',
#   '300',
#   '540',
#   '750',
#   '100',
#   '80',
#   '180',
#   '300',
#   '350',
#   '240',
#   '120',
#   '240',
#   '240',
#   '50',
#   '450',
#   '300',
#   '80',
#   '300',
#   '180',
#   '450',
#   '800',
#   '150',
#   '240',
#   '240',
#   '360',
#   '240',
#   '50',
#   '120',
#   '450',
#   '480',
#   '360',
#   '180',
#   '540',
#   '800',
#   '120',
#   '360',
#   '80',
#   '180',
#   '150',
#   '60',
#   '150',
#   '250',
#   '480',
#   '240',
#   '240',
#   '150',
#   '750',
#   '120',
#   '320',
#   '450',
#   '450',
#   '300',
#   '120',
#   '900',
#   '720',
#   '150',
#   '240',
#   '280',
#   '300',
#   '200',
#   '180',
#   '100',
#   '120',
#   '180',
#   '150',
#   '360',
#   '180',
#   '200',
#   '900',
#   '180',
#   '360',
#   '900',
#   '300',
#   '80',
#   '320',
#   '240',
#   '120',
#   '360',
#   '100',
#   '240',
#   '900',
#   '200',
#   '150',
#   '400',
#   '80',
#   '600',
#   '450',
#   '360',
#   '400',
#   '480',
#   '320',
#   '150',
#   '320',
#   '640',
#   '70',
#   '360',
#   '120',
#   '240',
#   '300',
#   '600',
#   '150',
#   '300',
#   '100',
#   '800',
#   '240',
#   '600',
#   '720',
#   '200',
#   '70',
#   '400',
#   '240',
#   '320',
#   '120',
#   '160',
#   '100',
#   '300',
#   '180',
#   '150',
#   '600',
#   '150',
#   '270',
#   '360',
#   '180',
#   '480',
#   '200',
#   '360',
#   '200',
#   '60',
#   '400',
#   '250',
#   '150',
#   '180',
#   '480',
#   '50',
#   '180',
#   '60',
#   '240',
#   '600',
#   '720',
#   '120',
#   '200',
#   '360',
#   '150',
#   '720',
#   '300',
#   '160',
#   '240',
#   '750',
#   '150',
#   '200',
#   '300',
#   '100',
#   '450',
#   '150',
#   '240',
#   '600',
#   '300',
#   '300',
#   '180',
#   '200',
#   '400',
#   '240',
#   '250',
#   '150',
#   '600',
#   '300',
#   '240',
#   '270',
#   '280',
#   '270',
#   '300',
#   '250',
#   '160',
#   '750',
#   '720',
#   '160',
#   '600',
#   '300',
#   '60',
#   '320',
#   '180',
#   '360',
#   '750',
#   '320',
#   '720',
#   '360',
#   '240',
#   '600',
#   '720',
#   '50',
#   '120',
#   '60',
#   '450',
#   '600',
#   '120',
#   '50',
#   '750',
#   '400',
#   '240',
#   '250',
#   '240',
#   '270',
#   '150',
#   '400',
#   '180',
#   '480',
#   '80',
#   '720',
#   '160',
#   '600',
#   '240',
#   '300',
#   '640',
#   '450',
#   '600',
#   '90',
#   '80',
#   '200',
#   '120',
#   '600',
#   '360',
#   '320',
#   '240',
#   '150',
#   '300',
#   '300',
#   '300',
#   '600',
#   '150',
#   '100',
#   '320',
#   '640',
#   '240',
#   '250',
#   '60',
#   '240',
#   '480',
#   '360',
#   '400',
#   '750',
#   '400',
#   '80',
#   '150',
#   '150',
#   '160',
#   '750',
#   '400',
#   '240',
#   '150',
#   '450',
#   '250',
#   '180',
#   '320',
#   '360',
#   '600',
#   '150',
#   '450',
#   '80',
#   '200',
#   '210',
#   '50',
#   '150',
#   '300',
#   '360',
#   '240',
#   '360',
#   '480',
#   '180',
#   '400',
#   '360',
#   '240',
#   '450',
#   '150',
#   '180',
#   '120',
#   '180',
#   '120',
#   '250',
#   '640',
#   '140',
#   '400',
#   '360',
#   '450',
#   '60',
#   '60',
#   '300',
#   '350',
#   '240',
#   '180',
#   '250',
#   '480',
#   '150',
#   '200',
#   '100',
#   '120',
#   '400',
#   '160',
#   '240',
#   '320',
#   '400',
#   '60',
#   '400',
#   '600',
#   '450',
#   '750',
#   '320',
#   '50',
#   '90',
#   '720',
#   '600',
#   '480',
#   '50',
#   '240',
#   '450',
#   '270',
#   '100',
#   '480',
#   '270',
#   '320',
#   '640',
#   '50',
#   '320',
#   '240',
#   '320',
#   '180',
#   '320',
#   '600',
#   '320',
#   '240',
#   '600',
#   '450',
#   '100',
#   '900',
#   ...]}

# %% [markdown]
# Converting to numeric

# %%
dataset['Unit Price'] = [float(item) for item in dataset['Unit Price']]
dataset['Quantity'] = [int(item) for item in dataset['Quantity']]
dataset['Total Price'] = [float(item) for item in dataset['Total Price']]

# %% [markdown]
# Total sales of store

# %%
sum(dataset['Total Price'])
# Out:
# 4583270.0

# %% [markdown]
# Monthwise sales totals

# %%
def month_from_date(date):
    return date.split('-')[1]

# %%
print(dataset['Date'][1000],month_from_date(dataset['Date'][1000]))
# Out:
# 2019-01-07 01
